# %% [markdown]
# # Parametric model of plate with multiple holes

# %% [markdown]
# ### Objective:
# In this example we'll setup a parametric model in PyMAPDL for a rectangular plate with multiple holes. The model is setup such that one can change the dimensions of the plate, the number of holes and their radius, the material properties and the pressure applied.
#
# The learning objectives of this demo are:
# * Launch PyMAPDL on a local machine
# * Setup and solve a parametric model using PyMAPDL
# * Interactive plotting of CAD, mesh, and results in Pythonic interface.

# %% [markdown]
# ### Model Details
# <div>
#     <img src="attachment:plate_with_hole.png" width="500"/>
# </div>
#
# #### Model parameters:
# * Length, width and depth of the plate
# * Number of holes
# * Raidus of the holes
# * Material properties (Young's modulus and Poisson's ratio)
# * Applied pressure

# %% [markdown]
# ## Step 1 - define all parameters

# %%
# All units in (m, Kg, s)
LENGTH = 5
WIDTH = 2.5
DEPTH = 0.1
RADIUS = 0.5
NUM = 3

E = 2e11
NU = 0.27

PRESSURE = 1000

# %% [markdown]
# # Step 2 - launch MAPDL and create geometry

# %%
from ansys.mapdl.core import launch_mapdl
mapdl = launch_mapdl()

mapdl.clear()
mapdl.prep7()
mapdl.block(0, LENGTH, 0, WIDTH, 0, DEPTH)
for i in range(1,NUM+1):
    mapdl.cyl4(i*LENGTH/(NUM+1),WIDTH/2,RADIUS,'','','',2*DEPTH)
mapdl.vsbv(1,'all')
mapdl.vplot('all')
# Out:
# Widget(value='<iframe src="http://localhost:61668/index.html?ui=P_0x27b7d6f4fb0_1&reconnect=auto" class="pyvis…

# %% [markdown]
# ## Step 3 - define material properties, mesh attributes and generate mesh.

# %%
mapdl.lesize("ALL", 0.15, layer1=1)

mapdl.mp('ex',1,E)
mapdl.mp('nuxy',1,NU)

mapdl.et(1,'SOLID186')
mapdl.mshape(1, "3D")
mapdl.mshkey(0)
mapdl.vmesh('all')
mapdl.eplot()
# Out:
# Widget(value='<iframe src="http://localhost:61668/index.html?ui=P_0x27b01a66510_2&reconnect=auto" class="pyvis…

# %% [markdown]
# ## Step 4 - apply loads and boundary conditions

# %%
mapdl.nsel('s','loc','x',0)
mapdl.d('all','all',0)

mapdl.nsel('s','loc','x', LENGTH)
mapdl.sf('all','pres',PRESSURE)

mapdl.allsel()
mapdl.finish()
# Out:
# ***** ROUTINE COMPLETED *****  CP =         0.719

# %% [markdown]
# ## Step 4 - solve the static problem

# %%
mapdl.slashsolu()
mapdl.solve()
mapdl.finish()
# Out:
# FINISH SOLUTION PROCESSING
#
#
#  ***** ROUTINE COMPLETED *****  CP =         3.625

# %%
# enter the solver routine and solve 
mapdl.slashsolu()
output = mapdl.solve()

print(output)
# Out:
# *** NOTE ***                            CP =       3.625   TIME= 16:46:44
#  The automatic domain decomposition logic has selected the MESH domain
#  decomposition method with 2 processes per solution.
#
#  *****  ANSYS SOLVE    COMMAND  *****
#
#  *** NOTE ***                            CP =       3.625   TIME= 16:46:44
#  There is no title defined for this analysis.
#
#  *** SELECTION OF ELEMENT TECHNOLOGIES FOR APPLICABLE ELEMENTS ***
#                 ---GIVE SUGGESTIONS ONLY---
#
#  ELEMENT TYPE         1 IS SOLID186. KEYOPT(2) IS ALREADY SET AS SUGGESTED.
#
#
#
#  *** ANSYS - ENGINEERING ANALYSIS SYSTEM  RELEASE 2022 R1          22.1     ***
#  DISTRIBUTED Ansys Mechanical Enterprise
#
#  00000000  VERSION=WINDOWS x64   16:46:44  JAN 04, 2024 CP=      3.625
#
#
#
#
#
#                        S O L U T I O N   O P T I O N S
#
#    PROBLEM DIMENSIONALITY. . . . . . . . . . . . .3-D
#    DEGREES OF FREEDOM. . . . . . UX   UY   UZ
#    ANALYSIS TYPE . . . . . . . . . . . . . . . . .STATIC (STEADY-STATE)
#    GLOBALLY ASSEMBLED MATRIX . . . . . . . . . . .SYMMETRIC
#
#  *** NOTE ***                            CP =       3.625   TIME= 16:46:44
#  Present time 0 is less than or equal to the previous time.  Time will
#  default to 1.
#
#  *** NOTE ***                            CP =       3.625   TIME= 16:46:44
#  The conditions for direct assembly have been met.  No .emat or .erot
#  files will be produced.
#
#
#
#      D I S T R I B U T E D   D O M A I N   D E C O M P O S E R
#
#   ...Number of elements: 3278
#   ...Number of nodes:    7036
#   ...Decompose to 2 CPU domains
#   ...Element load balance ratio =     1.000
#
#
#                       L O A D   S T E P   O P T I O N S
#
#    LOAD STEP NUMBER. . . . . . . . . . . . . . . .     1
#    TIME AT END OF THE LOAD STEP. . . . . . . . . .  1.0000
#    NUMBER OF SUBSTEPS. . . . . . . . . . . . . . .     1
#    STEP CHANGE BOUNDARY CONDITIONS . . . . . . . .    NO
#    PRINT OUTPUT CONTROLS . . . . . . . . . . . . .NO PRINTOUT
#    DATABASE OUTPUT CONTROLS. . . . . . . . . . . .ALL DATA WRITTEN
#                                                   FOR THE LAST SUBSTEP
#
#
#  SOLUTION MONITORING INFO IS WRITTEN TO FILE= file.mntr
#
#
#  Range of element maximum matrix coefficients in global coordinates
#  Maximum = 1.054464748E+11 at element 359.
#  Minimum = 8.300811073E+09 at element 1867.
#
#    *** ELEMENT MATRIX FORMULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1      3278  SOLID186      0.266   0.000081
#  Time at end of element matrix formulation CP = 3.84375.
#
#  DISTRIBUTED SPARSE MATRIX DIRECT SOLVER.
#   Number of equations =       20769,    Maximum wavefront =    168
#
#   Process memory allocated for solver              =    32.299 MB
#   Process memory required for in-core solution     =    31.072 MB
#   Process memory required for out-of-core solution =    18.006 MB
#
#   Total memory allocated for solver                =    64.242 MB
#   Total memory required for in-core solution       =    61.787 MB
#   Total memory required for out-of-core solution   =    35.451 MB
#
#  *** NOTE ***                            CP =       3.906   TIME= 16:46:44
#  The Distributed Sparse Matrix Solver is currently running in the
#  in-core memory mode.  This memory mode uses the most amount of memory
#  in order to avoid using the hard drive as much as possible, which most
#  often results in the fastest solution time.  This mode is recommended
#  if enough physical memory is present to accommodate all of the solver
#  data.
#  Distributed sparse solver maximum pivot= 1.238589586E+11 at node 5673
#  UX.
#  Distributed sparse solver minimum pivot= 6697804.76 at node 4513 UZ.
#  Distributed sparse solver minimum pivot in absolute value= 6697804.76
#  at node 4513 UZ.
#
#    *** ELEMENT RESULT CALCULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1      3278  SOLID186      0.109   0.000033
#
#    *** NODAL LOAD CALCULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1      3278  SOLID186      0.031   0.000010
#  *** LOAD STEP     1   SUBSTEP     1  COMPLETED.    CUM ITER =      1
#  *** TIME =   1.00000         TIME INC =   1.00000      NEW TRIANG MATRIX
#
#
#  *** ANSYS BINARY FILE STATISTICS
#   BUFFER SIZE USED= 16384
#         4.812 MB WRITTEN ON ASSEMBLED MATRIX FILE: file0.full
#         2.312 MB WRITTEN ON RESULTS FILE: file0.rst

# %% [markdown]
# ## Step 5 - plot the stress contours for the model

# %%
result = mapdl.result
result.plot_principal_nodal_stress(0,'seqv',background='w',show_edges=True,text_color='k',add_text=True)
# Out:
# Widget(value='<iframe src="http://localhost:61668/index.html?ui=P_0x27b01c30140_3&reconnect=auto" class="pyvis…

# %% [markdown]
# ## Step 6 - exit MAPDL

# %%
mapdl.exit()
# Out:
# Exception raised
# KeyError('8270614faac5700d37d4f1cb90c6ab25_186d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '8270614faac5700d37d4f1cb90c6ab25_186d'
#
# Exception raised
# KeyError('57dc9e528f6aa5262fa2d0f2ccaf5c5c_150L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '57dc9e528f6aa5262fa2d0f2ccaf5c5c_150L'
#
# Exception raised
# KeyError('4db14661b29a1174a844357dd5a25a15_186d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '4db14661b29a1174a844357dd5a25a15_186d'
#
# Exception raised
# KeyError('541a43fa7d3f990bd8bfbc8152b176bc_150L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '541a43fa7d3f990bd8bfbc8152b176bc_150L'
#
# Exception raised
# KeyError('d054404bf678b64ece94c09d76250416_96d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'd054404bf678b64ece94c09d76250416_96d'
#
# Exception raised
# KeyError('155d5f9bcf9d0c65078a22d6d0621119_75L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '155d5f9bcf9d0c65078a22d6d0621119_75L'
#
# Exception raised
# KeyError('b849da5de9259d09deb9c1f88c76b73b_96d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'b849da5de9259d09deb9c1f88c76b73b_96d'
#
# Exception raised
# KeyError('86e9f7acc6d91363cb2187965a666e3a_75L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '86e9f7acc6d91363cb2187965a666e3a_75L'
#
# Exception raised
# KeyError('3c50750ce4b2a3e58e962921698b0721_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '3c50750ce4b2a3e58e962921698b0721_66d'
#
# Exception raised
# KeyError('6208697349b3d6f8cfa89738cc57b836_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '6208697349b3d6f8cfa89738cc57b836_50L'
#
# Exception raised
# KeyError('583aa5c6f3363efb739e01acb3687263_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '583aa5c6f3363efb739e01acb3687263_66d'
#
# Exception raised
# KeyError('29139bd97c763ebf7cdf9cbf2b85e2fd_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '29139bd97c763ebf7cdf9cbf2b85e2fd_50L'
#
# Exception raised
# KeyError('b0a609746e241629e7fddd0e337f9e02_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'b0a609746e241629e7fddd0e337f9e02_66d'
#
# Exception raised
# KeyError('6208697349b3d6f8cfa89738cc57b836_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '6208697349b3d6f8cfa89738cc57b836_50L'
#
# Exception raised
# KeyError('35a46a61ae693630a35060ddd7521816_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '35a46a61ae693630a35060ddd7521816_66d'
#
# Exception raised
# KeyError('29139bd97c763ebf7cdf9cbf2b85e2fd_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '29139bd97c763ebf7cdf9cbf2b85e2fd_50L'
#
# Exception raised
# KeyError('d9366ba611ef3ea4935c03925ec32079_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'd9366ba611ef3ea4935c03925ec32079_66d'
#
# Exception raised
# KeyError('6208697349b3d6f8cfa89738cc57b836_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '6208697349b3d6f8cfa89738cc57b836_50L'
#
# Exception raised
# KeyError('0d7820db187a06731f44d0c0c878ec0c_66d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '0d7820db187a06731f44d0c0c878ec0c_66d'
#
# Exception raised
# KeyError('29139bd97c763ebf7cdf9cbf2b85e2fd_50L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '29139bd97c763ebf7cdf9cbf2b85e2fd_50L'
#
# Exception raised
# KeyError('bedb791068030faf29966d6b93e33ed9_1266d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'bedb791068030faf29966d6b93e33ed9_1266d'
#
# Exception raised
# KeyError('b4ab1a727af184c9d90cef7c99592583_1748L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: 'b4ab1a727af184c9d90cef7c99592583_1748L'
#
# Exception raised
# KeyError('86b0ded9c539c340f9a34025c8a76120_1254d')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '86b0ded9c539c340f9a34025c8a76120_1254d'
#
# Exception raised
# KeyError('009e2b350ea3f626d26c2d47a8f75a35_1725L')
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\wslink\protocol.py", line 332, in onMessage
#     results = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 33, in get_array
#     self.context.get_cached_data_array(data_hash, binary)
#   File "c:\Python312\Lib\site-packages\trame_vtk\modules\vtk\serializers\synchronization_context.py", line 35, in get_cached_data_array
#     cache_obj = self.data_array_cache[p_md5]
#                 ~~~~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: '009e2b350ea3f626d26c2d47a8f75a35_1725L'
